# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Configuration" data-toc-modified-id="Configuration-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Configuration</a></span></li><li><span><a href="#Visualization-Results" data-toc-modified-id="Visualization-Results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Visualization Results</a></span></li></ul></div>

# %%
import matplotlib.pyplot as plt

import json
import numpy as np

import sys
sys.path.append('../code')
from visualization import visualize_ROARnKAR

# %% [markdown]
# # Configuration

# %%
targets = ['mnist','cifar10']
methods = ['VBP','IB','DeconvNet','IG','GB','GC','GBGC']
ratio_lst = np.arange(0, 1, 0.1)

# %% [markdown]
# # Visualization Results

# %%
visualize_ROARnKAR(targets=targets,
                   methods=methods, 
                   ratio_lst=ratio_lst, 
                   eval_method='ROAR',
#                    savedir='../images/results/ROAR_result.jpg', 
                   dpi=150, 
                   size=(10,5), 
                   fontsize=15)

# %%
visualize_ROARnKAR(targets=targets,
                   methods=methods, 
                   ratio_lst=ratio_lst, 
                   eval_method='KAR',
#                    savedir='../images/results/KAR_result.jpg', 
                   dpi=150, 
                   size=(10,5), 
                   fontsize=15)
